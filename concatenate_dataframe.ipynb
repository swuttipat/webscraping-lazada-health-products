# %%
import pandas as pd
from datetime import datetime

# Assuming df_concatenated contains your DataFrame

# Generate the current timestamp
timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
timestamp
# Out:
# '20230809_024630'

# %%
health = pd.read_csv('health_and_wellness_20230807_220350.csv')
# Remove rows where 'Section' is 'Bone & Joint Support'


health.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 67479 entries, 0 to 67478
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             67479 non-null  int64
#  1   Section        67479 non-null  object
#  2   Name           67479 non-null  object
#  3   Price          67479 non-null  object
#  4   Total Sold     35686 non-null  object
#  5   Total Reviews  40170 non-null  object
#  6   Shop Location  67410 non-null  object
#  7   URL            67479 non-null  object
#  8   Catalog Pages  67479 non-null  int64
# dtypes: int64(2), object(7)
# memory usage: 4.6+ MB

# %%
# df_filtered = health[(health['Section'] != 'Multivitamins') & 
#                      (health['Section'] != 'Slimming Beverages') & 
#                      (health['Section'] != 'Meal Replacement')]


# df_filtered.Section.unique()

# %%
health.Section.unique()
# Out:
# array(['Acne Care', 'Beauty Supplements Value Sets', 'Breast Enlargement',
#        'Well Being Gifts & Value Sets', 'Skin Nourishment',
#        'Bone & Joint Support', 'Multivitamins', 'Digestive Care',
#        'Whitening', 'Herbs & Traditional Medicine',
#        'Nutritional Foods & Drinks', 'Brain & Memory',
#        'Slimming Beverages', 'Protein', 'Immunity',
#        'Sexual Health Vitamins', 'Hair & Nail',
#        'Stress, Sleep, and Anxiety', "Men's Health",
#        'Heart & Blood Pressure', 'Weight Management Value Sets',
#        'Meal Replacement', "Women's Health", 'Appetite Suppressant',
#        'Pregnancy Care', 'Detoxification', 'Mass Gainer', 'Pre-Workout',
#        'Fat Blockers & Burners'], dtype=object)

# %%
df0 = pd.read_csv('Food Supplement_20230809_023637.csv')
df0.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1020 entries, 0 to 1019
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1020 non-null   int64
#  1   Section        1020 non-null   object
#  2   Name           1020 non-null   object
#  3   Price          1020 non-null   object
#  4   Total Sold     1016 non-null   object
#  5   Total Reviews  782 non-null    object
#  6   Shop Location  1020 non-null   object
#  7   URL            1020 non-null   object
#  8   Catalog Pages  1020 non-null   int64
# dtypes: int64(2), object(7)
# memory usage: 71.8+ KB

# %%
df_concatenated = pd.concat([health, df0]).reset_index(drop=True)
df_concatenated.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 68499 entries, 0 to 68498
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             68499 non-null  int64
#  1   Section        68499 non-null  object
#  2   Name           68499 non-null  object
#  3   Price          68499 non-null  object
#  4   Total Sold     36702 non-null  object
#  5   Total Reviews  40952 non-null  object
#  6   Shop Location  68430 non-null  object
#  7   URL            68499 non-null  object
#  8   Catalog Pages  68499 non-null  int64
# dtypes: int64(2), object(7)
# memory usage: 4.7+ MB

# %%
df_concatenated.groupby(['Section']).count()
# Out:
#                                  Id  Name  Price  Total Sold  Total Reviews  \
# Section
# Acne Care                       760   760    760         153            274
# Appetite Suppressant           2440  2440   2440        1215           1409
# Beauty Supplements Value Sets  1480  1480   1480         423            532
# Bone & Joint Support           3960  3960   3960        2030           2634
# Brain & Memory                 3040  3040   3040        1234           1849
# Breast Enlargement              200   200    200         103            100
# Detoxification                 1760  1760   1760        1197           1259
# Digestive Care                 3959  3959   3959        1785           2177
# Fat Blockers & Burners         1720  1720   1720        1455           1531
# Food Supplement                1020  1020   1020        1016            782
# Hair & Nail                     800   800    800         468            584
# ...

# %%
df_concatenated.sample(20)
# Out:
#                Id                        Section  \
# 34508  1600036354                 Brain & Memory
# 17794  4133292227                  Multivitamins
# 65123  3994017797                    Pre-Workout
# 45271  4757827747                       Immunity
# 60224  4794534480           Appetite Suppressant
# 10502  4770242723               Skin Nourishment
# 32753  4788776377     Nutritional Foods & Drinks
# 19442  4799371551                 Digestive Care
# 34620  4787925435                 Brain & Memory
# 55367  4799464116   Weight Management Value Sets
# 5090   4787560154  Well Being Gifts & Value Sets
# 26944  4762811234   Herbs & Traditional Medicine
# 39778  4795495546                        Protein
# 55031  4791522348   Weight Management Value Sets
# 8438   2882590580               Skin Nourishment
# 132    4778969098                      Acne Care
# 67887  4236540839                Food Supplement
# 11247  4785084345           Bone & Joint Support
# ...

# %%
# Concatenate the timestamp to the file name
file_name = f"health_and_wellness_{timestamp}.csv"

# Save the DataFrame to a CSV file with the updated file name
df_concatenated.to_csv(file_name, index=False)
