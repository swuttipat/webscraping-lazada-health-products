# %%
import pandas as pd

df = pd.read_csv('health_and_wellness_20230802_160225.csv')

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16320 entries, 0 to 16319
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             16320 non-null  int64
#  1   Section        16320 non-null  object
#  2   Name           16320 non-null  object
#  3   Price          16320 non-null  object
#  4   Total Sold     9018 non-null   object
#  5   Total Reviews  10496 non-null  object
#  6   Shop Location  16320 non-null  object
#  7   URL            16320 non-null  object
#  8   Catalog Pages  16320 non-null  int64
# dtypes: int64(2), object(7)
# memory usage: 1.1+ MB

# %%
df.head()
# Out:
#            Id    Section                                               Name  \
# 0  4799179886  Acne Care     DHC Vitamin B-Mix วิตามินบีรวม (สำหรับ 20 วัน)
# 1  4795171651  Acne Care  ซิงค์ Vistra Zinc วิสทร้า ซิงค์ 15 มก. ขนาด 20...
# 2  4790242641  Acne Care  Blackmores  แบลคมอร์ส Bio Zinc A Chelate (90 T...
# 3  4789940606  Acne Care  1แถม1 กลูต้าวิตมี กลูต้าส้มเลือด Gluta With Me...
# 4  4787161067  Acne Care  🎌 DHC Vitamin B-Mix Persistent วิตามินบีรวม แบ...
#
#      Price Total Sold Total Reviews  Shop Location  \
# 0   ฿75.00        NaN           NaN       ปทุมธานี
# 1   ฿79.00        NaN           NaN      เชียงใหม่
# 2  ฿224.00        NaN           NaN       สุรินทร์
# 3  ฿290.00        NaN           NaN       อุดรธานี
# 4  ฿149.00        NaN           NaN  กรุงเทพมหานคร
#
#                                                  URL  Catalog Pages
# 0  https://www.lazada.co.th/products/dhc-vitamin-...              1
# ...

# %%
# Transform column name to lowercase and replace ' ' with '_'
df.columns = df.columns.str.replace(' ', '_').str.lower()

# Fill missing values
df['total_sold'].fillna('0', inplace=True)
df['total_reviews'].fillna('0', inplace=True)
df['shop_location'].fillna('Unknown', inplace=True)

# Remove non-numeric characters using regex and convert to appropriate data types
df['price'] = df['price'].str.replace('฿', '', regex=True).str.replace(',', '', regex=True).astype(float)

# Cleaning 'total_sold' column
df['total_sold'] = df['total_sold'].str.replace('[^0-9.]+', '', regex=True)
df['total_sold'] = df['total_sold'].replace('9999+', '10000').astype(int)

# Cleaning 'total_reviews' column
df['total_reviews'] = df['total_reviews'].str.replace('[^0-9.]+', '', regex=True).astype(int)

# Display the first few rows of the cleaned dataframe
df.head()
# Out:
#            id    section                                               name  \
# 0  4799179886  Acne Care     DHC Vitamin B-Mix วิตามินบีรวม (สำหรับ 20 วัน)
# 1  4795171651  Acne Care  ซิงค์ Vistra Zinc วิสทร้า ซิงค์ 15 มก. ขนาด 20...
# 2  4790242641  Acne Care  Blackmores  แบลคมอร์ส Bio Zinc A Chelate (90 T...
# 3  4789940606  Acne Care  1แถม1 กลูต้าวิตมี กลูต้าส้มเลือด Gluta With Me...
# 4  4787161067  Acne Care  🎌 DHC Vitamin B-Mix Persistent วิตามินบีรวม แบ...
#
#    price  total_sold  total_reviews  shop_location  \
# 0   75.0           0              0       ปทุมธานี
# 1   79.0           0              0      เชียงใหม่
# 2  224.0           0              0       สุรินทร์
# 3  290.0           0              0       อุดรธานี
# 4  149.0           0              0  กรุงเทพมหานคร
#
#                                                  url  catalog_pages
# 0  https://www.lazada.co.th/products/dhc-vitamin-...              1
# ...

# %%
df.groupby(['section']).count()
# Out:
#                                  id  name  price  total_sold  total_reviews  \
# section
# Acne Care                       760   760    760         760            760
# Beauty Supplements Value Sets  1480  1480   1480        1480           1480
# Bone & Joint Support           3960  3960   3960        3960           3960
# Breast Enlargement              200   200    200         200            200
# Meal Replacement                 40    40     40          40             40
# Multivitamins                  1600  1600   1600        1600           1600
# Skin Nourishment               4160  4160   4160        4160           4160
# Slimming Beverages               40    40     40          40             40
# Well Being Gifts & Value Sets  4080  4080   4080        4080           4080
#
#                                shop_location   url  catalog_pages
# section
# Acne Care                                760   760            760
# ...
